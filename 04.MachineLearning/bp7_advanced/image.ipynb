# %%
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
vgg = VGG16()

# %%
import numpy as np
from PIL import Image

img = np.array(Image.open("../static/img/opencvtest.jpg").resize((224, 224)))

yhat = vgg.predict(img.reshape(-1, 224, 224, 3))
label_key = np.argmax(yhat)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
#사진넣으니 결과가 뙇 bald_eagle (66.91%)
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# Pomeranian (45.39%)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(11,11))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
image = cv2.imread('../static/img/opencvtest.jpg', cv2.IMREAD_COLOR)
plt.imshow(image)
